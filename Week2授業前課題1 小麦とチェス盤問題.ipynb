# %% [markdown]
# # 少ないマスで考える

# %% [markdown]
# まずは4マスの板に小麦の粒を並べていくことを考えます。配列（リスト）の1つの要素を1つのマスに見立てています。
#
# Pythonのリストとfor文を使い次のように作ることができます。
#
# 《サンプルコード》

# %%
n_squares = 4
small_board_list = [1]

for _ in range(n_squares - 1):
    small_board_list.append(2*small_board_list[-1])
print("4マスの板に小麦を並べる（リスト）：{}".format(small_board_list))
# Out:
# 4マスの板に小麦を並べる（リスト）：[1, 2, 4, 8]

# %%
import numpy as np

small_board_ndarray = np.array(small_board_list)
print("4マスの板に小麦を並べる（ndarray）：{}".format(small_board_ndarray))
# Out:
# 4マスの板に小麦を並べる（ndarray）：[1 2 4 8]

# %% [markdown]
# # 【問題1】2×2マスのチェス盤の小麦の数

# %%
q1_n_squares = 4
q1_small_board_list = [1]

for _ in range(q1_n_squares - 1):
    q1_small_board_list.append(2*q1_small_board_list[-1])

q1_small_board_ndarray = np.array(q1_small_board_list).reshape(2,2)
print("4マスの板に小麦を並べる（ndarray）：{}".format(q1_small_board_ndarray))
# Out:
# 4マスの板に小麦を並べる（ndarray）：[[1 2]
#  [4 8]]

# %% [markdown]
# # 4.8×8マスのチェス盤

# %% [markdown]
# # 【問題2】n×mマスへの拡張

# %% [markdown]
# n×mマスのチェス盤の小麦の数を記したndarrayを返す関数を作成してください。そして、この関数を使い8×8マスのチェス盤の小麦の数を求めてください。

# %%
def wheat_count(n_squares,n_mass,m_mass):
    small_board_list = [1]
    for _ in range (n_squares -1):
        small_board_list.append(2*small_board_list[-1])

    small_board_ndarray = np.array(small_board_list).reshape(n_mass,m_mass)
    return small_board_ndarray

# %%
print("8マスの板に小麦を並べる（ndarray）：{}".format(wheat_count(n_squares = 64,n_mass = 8,m_mass = 8)))
# Out:
# 8マスの板に小麦を並べる（ndarray）：[[1.00000000e+00 2.00000000e+00 4.00000000e+00 8.00000000e+00
#   1.60000000e+01 3.20000000e+01 6.40000000e+01 1.28000000e+02]
#  [2.56000000e+02 5.12000000e+02 1.02400000e+03 2.04800000e+03
#   4.09600000e+03 8.19200000e+03 1.63840000e+04 3.27680000e+04]
#  [6.55360000e+04 1.31072000e+05 2.62144000e+05 5.24288000e+05
#   1.04857600e+06 2.09715200e+06 4.19430400e+06 8.38860800e+06]
#  [1.67772160e+07 3.35544320e+07 6.71088640e+07 1.34217728e+08
#   2.68435456e+08 5.36870912e+08 1.07374182e+09 2.14748365e+09]
#  [4.29496730e+09 8.58993459e+09 1.71798692e+10 3.43597384e+10
#   6.87194767e+10 1.37438953e+11 2.74877907e+11 5.49755814e+11]
#  [1.09951163e+12 2.19902326e+12 4.39804651e+12 8.79609302e+12
#   1.75921860e+13 3.51843721e+13 7.03687442e+13 1.40737488e+14]
#  [2.81474977e+14 5.62949953e+14 1.12589991e+15 2.25179981e+15
#   4.50359963e+15 9.00719925e+15 1.80143985e+16 3.60287970e+16]
#  [7.20575940e+16 1.44115188e+17 2.88230376e+17 5.76460752e+17
# ...

# %% [markdown]
# # 【問題3】小麦の数の合計

# %% [markdown]
# 8×8マスのチェス盤の小麦の数の合計を求めてください。また、各列の平均を求め、それを棒グラフで可視化してください。
#
# 棒グラフはサンプルコードを用意しています。
#
# 《棒グラフのサンプルコード》

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.xlabel("column")
plt.ylabel("number")
plt.title("number in each column")
plt.bar(np.arange(1,4), np.array([1, 2, 3]))
plt.show()

# %% [markdown]
# matplotlib.pyplot.bar — Matplotlib 3.1.0 documentation[https://matplotlib.org/3.1.0/api/_as_gen/matplotlib.pyplot.bar.html]

# %% [markdown]
# ①小麦の合計数

# %%
sum_result = wheat_count(n_squares = 64,n_mass = 8,m_mass = 8).sum()
print(sum_result)
# Out:
# 1.8446744073709552e+19

# %%
print("8マスのチェス盤の小麦の合計：{:.1e}".format(sum_result))
# Out:
# 8マスのチェス盤の小麦の合計：1.8e+19

# %% [markdown]
# ②各列の平均

# %%
mean_result = np.mean(wheat_count(n_squares = 64,n_mass = 8,m_mass = 8),axis=0)
print(mean_result)
# Out:
# [9.04252160e+15 1.80850432e+16 3.61700864e+16 7.23401728e+16
#  1.44680346e+17 2.89360691e+17 5.78721383e+17 1.15744277e+18]

# %%
print("8マスのチェス盤の小麦の各列の平均：{}".format(mean_result))
# Out:
# 8マスのチェス盤の小麦の各列の平均：[9.04252160e+15 1.80850432e+16 3.61700864e+16 7.23401728e+16
#  1.44680346e+17 2.89360691e+17 5.78721383e+17 1.15744277e+18]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.xlabel("columns")
plt.ylabel("mean_wheat_count")
plt.title("mean in each column")
plt.bar(np.arange(1,9),mean_result)
plt.show()

# %% [markdown]
# # 【問題4】小麦の数のヒートマップ

# %% [markdown]
# 8×8マスのチェス盤の小麦の数をヒートマップとして可視化してください。
#
# ヒートマップはサンプルコードを用意しています。
#
# 《ヒートマップのサンプルコード》
#
# 4行2列の配列のヒートマップです。値が小さいところが紫、大きいところが黄色になっています。

# %%
plt.xlabel("column")
plt.ylabel("row")
plt.title("heatmap")
plt.pcolor(np.array([0, 1, 3, 5, 7, 9, 11, 13]).reshape(4, 2))
plt.show()

# %% [markdown]
# matplotlib.pyplot.pcolor — Matplotlib 3.1.0 documentation[https://matplotlib.org/3.1.0/api/_as_gen/matplotlib.pyplot.pcolor.html]

# %%
plt.xlabel("columns")
plt.ylabel("mean_wheat_count")
plt.title("mean in each column")
plt.pcolor(wheat_count(n_squares = 64,n_mass = 8,m_mass = 8))
plt.show()

# %% [markdown]
# # 5.チェス盤の後半

# %% [markdown]
# アメリカの発明家レイ・カーツワイルはこの逸話を引用し、「チェス盤の後半」というフレーズを作りました。技術の進歩ははじめの内は社会に対して目立った影響が感じられなくとも、倍に倍にと進んでいくと、チェス盤の後半にさしかかったころから、急激な変化を起こすということを伝えています。

# %% [markdown]
# # 【問題5】後半は前半の何倍か

# %% [markdown]
# チェス盤の後半にある小麦の数は前半にある小麦の数の何倍かを求めてください。前半とは配列の0から3行目、後半は4から7行目です。

# %%
wheat = wheat_count(n_squares = 64,n_mass = 8,m_mass = 8)
first_half = wheat[:4].sum()
second_half = wheat[4:].sum()

print("チェス盤の後半にある小麦の数は前半にある小麦の{}倍".format(second_half/first_half))
# Out:
# チェス盤の後半にある小麦の数は前半にある小麦の4294967296.0倍

# %% [markdown]
# # 6.他の計算方法

# %% [markdown]
# はじめのサンプルコードではPythonのリストとfor文を使っていましたが、他の方法も考えられます。
#
# ndarrayのnp.append()とfor文を使うと次のように作ることができます。
#
# 《サンプルコード（np.append()）》

# %%
n_squares = 4
small_board_ndarray = np.array([1])
for _ in range(n_squares - 1):
    small_board_ndarray = np.append(small_board_ndarray, 2*small_board_ndarray[-1])
print("4マスの板に小麦を並べる（ndarray）：{}".format(small_board_ndarray))
# Out:
# 4マスの板に小麦を並べる（ndarray）：[1 2 4 8]

# %% [markdown]
# ブロードキャストを活用することで、次のようにも作ることができます。
#
# 《サンプルコード（ブロードキャスト）》

# %%
n_squares = 4
indices_of_squares = np.arange(n_squares)
small_board_ndarray = 2**indices_of_squares
print("4マスの板に小麦を並べる（ndarray）：{}".format(small_board_ndarray))
# Out:
# 4マスの板に小麦を並べる（ndarray）：[1 2 4 8]

# %% [markdown]
# ndarrayの型
# なお、これらの方法で64マスの小麦の数を調べたい場合、型の問題が出てきます。

# %%
n_squares = 64
board_ndarray = np.array([1])
for _ in range(n_squares - 1):
    board_ndarray = np.append(board_ndarray, 2*board_ndarray[-1])
print("最後のマスの小麦の数：{}".format(board_ndarray[-1])) # -9223372036854775808
# Out:
# 最後のマスの小麦の数：0
# C:\Users\libre\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in long_scalars
#   after removing the cwd from sys.path.

# %%
n_squares = 64
indices_of_squares = np.arange(n_squares)
board_ndarray = 2**indices_of_squares
print("最後のマスの小麦の数：{}".format(board_ndarray[-1])) # -9223372036854775808
# Out:
# 最後のマスの小麦の数：0

# %% [markdown]
# 最後の64マス目が-9223372036854775808と負の数になり明らかに間違っています。このndarrayの型を見ると、次のように int64 です。

# %%
print(board_ndarray.dtype) # int64
# Out:
# int32

# %% [markdown]
# int64は64ビットの整数型で、-9,223,372,036,854,775,808 ~ 9,223,372,036,854,775,807 の範囲の整数値しか扱えないことを示しています。この値は -2の64乗から2の64乗-1 です。そのため、2の64乗になる64マス目の値が範囲外となり、負の値として出てきてしまっているのです。
#
# Pythonの整数型（int）にはこのような制限がありませんが、ndarrayは高速な計算が行える反面、こういった制約があり、型で扱える範囲を意識しておく必要があります。
#
# 今回は正の値しか利用しないため、 uint64 を使用することで解決します。 0 ~ 18,446,744,073,709,551,615 を扱うことができます。astypeメソッドを使うことで型を変換できるので、累乗の計算前にこれを使いndarrayをuint64型にしておきます。

# %%
n_squares = 64
indices_of_squares = np.arange(n_squares).astype(np.uint64)
board_ndarray = 2**indices_of_squares
print("最後のマスの小麦の数：{}".format(board_ndarray[-1])) # 9223372036854775808
# Out:
# 最後のマスの小麦の数：9223372036854775808

# %% [markdown]
# これで正しく計算ができました。

# %% [markdown]
# # 【問題6】他の計算方法によるn×mマスへの拡張

# %% [markdown]
# 問題2と同様の「n×mマスのチェス盤の小麦の数を記したndarrayを返す関数」を、np.append()を使ったものと、ブロードキャストを使ったもので新たに作成してください。
#
# それらの関数を使い8×8マスのチェス盤の小麦の数を再び求めてください。

# %%
def board_npappend(n_squares):

    small_board_ndarray = np.array([1])
    for _ in range(n_squares - 1):
        small_board_ndarray = np.append(small_board_ndarray, 2*small_board_ndarray[-1])
    print(small_board_ndarray.astype(np.uint64).sum())

board_npappend(64)
# Out:
# 18446744073709551615
# C:\Users\libre\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: overflow encountered in long_scalars

# %%
def broad_squares(n_squares):
    indices_of_squares = np.arange(n_squares)
    small_board_ndarray = 2**indices_of_squares
    print(small_board_ndarray.astype(np.uint64).sum())

broad_squares(64)
# Out:
# 18446744073709551615

# %% [markdown]
# # 【問題7】計算時間の比較

# %% [markdown]
# 3種類の方法を見てきました。それぞれの計算時間をJupyter Notebookの%%timeitを用いて計測し、比較と考察を行ってください。
#
# %%timeitはセル内のコードを複数回実行し、その平均実行時間を出力する働きをします。
#
# 《%%timeitの例》

# %%
# %%timeit
a = np.array([1, 2, 3])
b = np.array([1, 2, 3])
c = a + b
# Out:
# 4.92 µs ± 75.8 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %% [markdown]
# 8x8盤の処理にて検証

# %%
# %%timeit
wheat_count(n_squares = 64,n_mass = 8,m_mass = 8).sum()
# Out:
# 43.5 µs ± 2.33 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %%timeit
board_npappend(64)
# Out:
# C:\Users\libre\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: overflow encountered in long_scalars
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# ...

# %%
# %%timeit
broad_squares(64)
# Out:
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# 18446744073709551615
# ...

# %% [markdown]
# 2x2盤の処理にて検証

# %%
# %%timeit
wheat_count(n_squares = 4,n_mass = 2,m_mass = 2).sum()
# Out:
# 11.2 µs ± 804 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %%timeit
board_npappend(4)
# Out:
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# ...

# %%
# %%timeit
broad_squares(4)
# Out:
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# ...

# %% [markdown]
# # <考察>

# %% [markdown]
# 8x8
# <br>リスト追加後np変換し処理する方法　43.5 µs ± 2.33 µs
# <br>npのリストから処理する方法　　2.03 ms ± 444 µs
# <br>リストを作成せずにnp上で計算する方法　272 µs ± 32.8 µs
#
# 2x2
# <br>リスト追加後np変換し処理する方法　11.2 µs ± 804 ns
# <br>npのリストから処理する方法　　340 µs ± 80.8 µs
# <br>リストを作成せずにnp上で計算する方法　265 µs ± 55.8 µs
#
# npのリストを作成し、追加する処理は通常のリストへ追加して処理する場合よりもかなり遅くなりました。
# <br>ブロードキャストでリストを作成せずnpの計算処理に頼る方法としては、マス盤が増えても処理速度がほぼ変わらなかった結果から
# <br>大量に計算が必要になってくると、リスト追加する方法よりも早くなると考えられます。
